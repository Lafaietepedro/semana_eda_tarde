# %%
! pip install pandas
! pip install matplotlib
! pip install seaborn

# %%
import pandas as pd

# %%
df_pesquisa_musical = pd.read_csv('datasets/pesquisa_musical.csv')
df_pesquisa_musical.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
df_pesquisa_musical = df_pesquisa_musical.drop('Carimbo de data/hora', axis='columns')

# %%
df_pesquisa_musical.head()
# Out:
#    Avalie os estilos musicais [rock]  Avalie os estilos musicais [hip hop]  \
# 0                                  3                                     1
# 1                                  5                                     3
# 2                                  1                                     5
# 3                                  1                                     5
# 4                                  5                                     4
#
#    Avalie os estilos musicais [mpb]  Avalie os estilos musicais [reggae]  \
# 0                                 1                                    1
# 1                                 5                                    2
# 2                                 1                                    1
# 3                                 4                                    4
# 4                                 3                                    4
#
# ...

# %%
df_pesquisa_musical.columns = ['Rock','Hip Hop','MPB','Reggae','Funk','Sertanejo','Gospel','Eletrônica']

# %%
df_pesquisa_musical.head()
# Out:
#    Rock  Hip Hop  MPB  Reggae  Funk  Sertanejo  Gospel  Eletrônica
# 0     3        1    1       1     1          1       1           3
# 1     5        3    5       2     1          3       1           5
# 2     1        5    1       1     1          1       1           5
# 3     1        5    4       4     4          1       1           5
# 4     5        4    3       4     1          1       2           5

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df_pesquisa_musical.mean().plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.boxplot(df_pesquisa_musical)
# Out:
# <Axes: >

# %%
sns.boxplot(df_pesquisa_musical.mean())
# Out:
# <Axes: >

# %%
sns.histplot(df_pesquisa_musical,kde=True,bins='auto')
# Out:
# <Axes: ylabel='Count'>
